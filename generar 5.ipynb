# %%
from pymongo  import MongoClient
from datetime import datetime
import random
from tqdm import tqdm

# %%
client = MongoClient('localhost', 27017)
db = client['IAtest']
analisis_predictivos = db['modelos_de_analisis']

# %%
acciones_preventivas = [
    "Mantener reposo en cama",
    "Beber líquidos abundantes",
    "Tomar medicamentos para el dolor de cabeza",
    "Consultar a un médico",
    "Realizar ejercicios de respiración profunda",
    "Evitar alimentos grasosos",
    "Aplicar compresas frías en la frente",
    "Monitorear la presión arterial regularmente",
]

# %%
def generar_data(paciente_id):
    now = datetime.now()
    analisis = {
        "paciente_id": paciente_id,
        "fecha": now,
        "sintomas": {
            "dolor_de_cabeza": 1,
            "fatiga": 1,
            "nauseas": 1,
            "mareos": 1,
            "dolor_abdominal": 0,
            "fiebre": 0,
            "dificultad_respirar": 0,
            "dolor_pecho": 0,
            "sangrado": 0
        },
        "signos_vitales": {
            "temperatura": 36,
            "presion_sistolica": 120,
            "presion_diastolica": 80,
            "frecuencia_cardiaca": 70,
            "glucosa": 100,
            "presion_arterial": 1.5
        },
        "accion_preventiva": "Mantener reposo en cama"
    }
    return analisis

# %%
def generar_data(paciente_id):
    now = datetime.now()
    analisis = {
        "paciente_id": paciente_id,
        "fecha": now,
        "sintomas": {
            "dolor_de_cabeza": 1,
            "fatiga": 1,
            "nauseas": 1,
            "mareos": 0,
            "dolor_abdominal": 1,
            "fiebre": 1,
            "dificultad_respirar": 0,
            "dolor_pecho": 0,
            "sangrado": 0
        },
        "signos_vitales": {
            "temperatura": 37.5,
            "presion_sistolica": 118,
            "presion_diastolica": 78,
            "frecuencia_cardiaca": 72,
            "glucosa": 105,
            "presion_arterial": 1.6
        },
        "accion_preventiva": "Beber líquidos abundantes"
    }
    return analisis

# %%
def generar_data(paciente_id):
    now = datetime.now()
    analisis = {
        "paciente_id": paciente_id,
        "fecha": now,
        "sintomas": {
            "dolor_de_cabeza": 1,
            "fatiga": 0,
            "nauseas": 0,
            "mareos": 0,
            "dolor_abdominal": 0,
            "fiebre": 0,
            "dificultad_respirar": 0,
            "dolor_pecho": 0,
            "sangrado": 0
        },
        "signos_vitales": {
            "temperatura": 36,
            "presion_sistolica": 120,
            "presion_diastolica": 80,
            "frecuencia_cardiaca": 70,
            "glucosa": 100,
            "presion_arterial": 1.5
        },
        "accion_preventiva": "Tomar medicamentos para el dolor de cabeza"
    }
    return analisis

# %%
def generar_data(paciente_id):
    now = datetime.now()
    analisis = {
        "paciente_id": paciente_id,
        "fecha": now,
        "sintomas": {
            "dolor_de_cabeza": 1,
            "fatiga": 1,
            "nauseas": 1,
            "mareos": 1,
            "dolor_abdominal": 0,
            "fiebre": 1,
            "dificultad_respirar": 1,
            "dolor_pecho": 1,
            "sangrado": 0
        },
        "signos_vitales": {
            "temperatura": 38,
            "presion_sistolica": 122,
            "presion_diastolica": 82,
            "frecuencia_cardiaca": 68,
            "glucosa": 95,
            "presion_arterial": 1.7
        },
        "accion_preventiva": "Consultar a un médico"
    }
    return analisis

# %%
def generar_data(paciente_id):
    now = datetime.now()
    analisis = {
        "paciente_id": paciente_id,
        "fecha": now,
        "sintomas": {
            "dolor_de_cabeza": 0,
            "fatiga": 1,
            "nauseas": 0,
            "mareos": 1,
            "dolor_abdominal": 0,
            "fiebre": 0,
            "dificultad_respirar": 1,
            "dolor_pecho": 1,
            "sangrado": 0
        },
        "signos_vitales": {
            "temperatura": 36.6,
            "presion_sistolica": 119,
            "presion_diastolica": 79,
            "frecuencia_cardiaca": 75,
            "glucosa": 100,
            "presion_arterial": 1.9
        },
        "accion_preventiva": "Realizar ejercicios de respiración profunda"
    }
    return analisis

# %%
def generar_data(paciente_id):
    now = datetime.now()
    analisis = {
        "paciente_id": paciente_id,
        "fecha": now,
        "sintomas": {
            "dolor_de_cabeza": 0,
            "fatiga": 0,
            "nauseas": 0,
            "mareos": 0,
            "dolor_abdominal": 0,
            "fiebre": 0,
            "dificultad_respirar": 1,
            "dolor_pecho": 0,
            "sangrado": 0
        },
        "signos_vitales": {
            "temperatura": 36.6,
            "presion_sistolica": 130,
            "presion_diastolica": 90,
            "frecuencia_cardiaca": 80,
            "glucosa": 110,
            "presion_arterial": 1.9
        },
        "accion_preventiva": "Evitar alimentos grasosos"
    }
    return analisis

# %%
def generar_data(paciente_id):
    now = datetime.now()
    analisis = {
        "paciente_id": paciente_id,
        "fecha": now,
        "sintomas": {
            "dolor_de_cabeza": 0,
            "fatiga": 0,
            "nauseas": 0,
            "mareos": 0,
            "dolor_abdominal": 0,
            "fiebre": 1,
            "dificultad_respirar": 0,
            "dolor_pecho": 0,
            "sangrado": 0
        },
        "signos_vitales": {
            "temperatura": 38.2,
            "presion_sistolica": 120,
            "presion_diastolica": 80,
            "frecuencia_cardiaca": 70,
            "glucosa": 100,
            "presion_arterial": 1.5
        },
        "accion_preventiva": "Aplicar compresas frías en la frente"
    }
    return analisis

# %%
def generar_data(paciente_id):
    now = datetime.now()
    analisis = {
        "paciente_id": paciente_id,
        "fecha": now,
        "sintomas": {
            "dolor_de_cabeza": 1,
            "fatiga": 0,
            "nauseas": 0,
            "mareos": 0,
            "dolor_abdominal": 0,
            "fiebre": 1,
            "dificultad_respirar": 0,
            "dolor_pecho": 0,
            "sangrado": 0
        },
        "signos_vitales": {
            "temperatura": 36.5,
            "presion_sistolica": 130,
            "presion_diastolica": 60,
            "frecuencia_cardiaca": 70,
            "glucosa": 100,
            "presion_arterial": 2.166
        },
        "accion_preventiva": "Monitorear la presión arterial regularmente"
    }
    return analisis

# %%
total_analisis = 100000 
batch_size = 1000
for cont in tqdm(range(0, total_analisis, batch_size)):
    batch = [generar_data(cont) for cont in range(batch_size)]
    analisis_predictivos.insert_many(batch)
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 65.15it/s]
